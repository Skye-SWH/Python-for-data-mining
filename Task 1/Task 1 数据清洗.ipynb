# %% [markdown]
# #### 任务1：对数据进行探索和分析
#
# - 数据类型的分析
# - 无关特征删除
# - 数据类型转换
# - 缺失值处理
# - 要求：数据切分方式 - 三七分，其中测试集30%，训练集70%，随机种子设置为2018

# %%
# 导入数据 

import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv('data.csv', encoding='gbk')

# %%
# 一个cell做多个输出

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %% [markdown]
# #### 数据类型的分析

# %%
df.head()
df.info()
df.dtypes.value_counts()
# Out:
#    Unnamed: 0   custid                          trade_no bank_card_no  \
# 0           5  2791858  20180507115231274000000023057383          卡号1
# 1          10   534047  20180507121002192000000023073000          卡号1
# 2          12  2849787  20180507125159718000000023114911          卡号1
# 3          13  1809708  20180507121358683000000388283484          卡号1
# 4          14  2499829  20180507115448545000000388205844          卡号1
#
#    low_volume_percent  middle_volume_percent  \
# 0                0.01                   0.99
# 1                0.02                   0.94
# 2                0.04                   0.96
# 3                0.00                   0.96
# 4                0.01                   0.99
#
#    take_amount_in_later_12_month_highest  trans_amount_increase_rate_lately  \
# 0                                      0                               0.90
# 1                                   2000                               1.28
# ...

# %% [markdown]
# #### 无关特征删除

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                  0
# custid                                      0
# trade_no                                    0
# bank_card_no                                0
# low_volume_percent                          2
# middle_volume_percent                       2
# take_amount_in_later_12_month_highest       0
# trans_amount_increase_rate_lately           3
# trans_activity_month                        2
# trans_activity_day                          2
# transd_mcc                                  2
# trans_days_interval_filter                  8
# trans_days_interval                         2
# regional_mobility                           2
# student_feature                          2998
# repayment_capability                        0
# is_high_user                                0
# number_of_trans_from_2011                   2
# first_transaction_time                      2
# historical_trans_amount                     0
# ...

# %%
data = df.drop(['student_feature','Unnamed: 0','id_name', 'latest_query_time','loans_latest_time','bank_card_no', 'source','custid','trade_no'], axis=1)
data.describe()
# Out:
#        low_volume_percent  middle_volume_percent  \
# count         4752.000000            4752.000000
# mean             0.021806               0.901294
# std              0.041527               0.144856
# min              0.000000               0.000000
# 25%              0.010000               0.880000
# 50%              0.010000               0.960000
# 75%              0.020000               0.990000
# max              1.000000               1.000000
#
#        take_amount_in_later_12_month_highest  \
# count                            4754.000000
# mean                             1940.197728
# std                              3923.971494
# min                                 0.000000
# 25%                                 0.000000
# 50%                               500.000000
# 75%                              2000.000000
# max                             68000.000000
#
#        trans_amount_increase_rate_lately  trans_activity_month  \
# ...

# %% [markdown]
# #### 数据类型转换

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4754 entries, 0 to 4753
# Data columns (total 81 columns):
# low_volume_percent                            4754 non-null int64
# middle_volume_percent                         4754 non-null int64
# take_amount_in_later_12_month_highest         4754 non-null int64
# trans_amount_increase_rate_lately             4754 non-null int64
# trans_activity_month                          4754 non-null int64
# trans_activity_day                            4754 non-null int64
# transd_mcc                                    4754 non-null int64
# trans_days_interval_filter                    4754 non-null int64
# trans_days_interval                           4754 non-null int64
# regional_mobility                             4754 non-null int64
# repayment_capability                          4754 non-null int64
# is_high_user                                  4754 non-null int64
# number_of_trans_from_2011                     4754 non-null int64
# ...

# %%
# data[column] = data[column].astype('int64')

# %%
# 查找object类型的列名
ob = data.select_dtypes(include='object').columns.values
ob
# Out:
# array(['reg_preference_for_trad'], dtype=object)

# %%
data = df.drop('reg_preference_for_trad', axis=1)

# %% [markdown]
# #### 缺失值处理

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                                  0
# custid                                      0
# trade_no                                    0
# bank_card_no                                0
# low_volume_percent                          2
# middle_volume_percent                       2
# take_amount_in_later_12_month_highest       0
# trans_amount_increase_rate_lately           3
# trans_activity_month                        2
# trans_activity_day                          2
# transd_mcc                                  2
# trans_days_interval_filter                  8
# trans_days_interval                         2
# regional_mobility                           2
# student_feature                          2998
# repayment_capability                        0
# is_high_user                                0
# number_of_trans_from_2011                   2
# first_transaction_time                      2
# historical_trans_amount                     0
# ...

# %%
# 找到有缺失值的列

# def miss_columns(df):
#     miss_columns = []
#     for column in df:
#         if sum(pd.isnull(df[column])) > 0:
#             miss_columns.append(column)
#     return miss_columns

# miss_columns = miss_columns(data)
# len(miss_columns)
# Out:
# 73

# %%
#用均值填充
# for col in miss_columns:
#         data[col]=data[col].fillna(data[col].mean())


data['loans_credibility_behavior']=data['loans_credibility_behavior'].fillna(data['loans_credibility_behavior'].mean())

data.isnull().sum() 
data.info()
# Out:
# Unnamed: 0                                 0
# custid                                     0
# trade_no                                   0
# bank_card_no                               0
# low_volume_percent                         0
# middle_volume_percent                      0
# take_amount_in_later_12_month_highest      0
# trans_amount_increase_rate_lately          0
# trans_activity_month                       0
# trans_activity_day                         0
# transd_mcc                                 0
# trans_days_interval_filter                 0
# trans_days_interval                        0
# regional_mobility                          0
# student_feature                            0
# repayment_capability                       0
# is_high_user                               0
# number_of_trans_from_2011                  0
# first_transaction_time                     0
# historical_trans_amount                    0
# historical_trans_day                       0
# ...

# %% [markdown]
# #### 数据切分方式 - 三七分，其中测试集30%，训练集70%，随机种子设置为2018

# %%
Y=data['status']
X = data.drop(['status'], axis=1)

X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.3, random_state=2018)

X_train,X_test,y_train,y_test
# Out:
# (      Unnamed: 0   custid                          trade_no bank_card_no  \
#  110          296  3302657  20180504182022079000000381847944          卡号1
#  3394        8545  2733732  20180507115234629000000023058189          卡号1
#  3052        7641  2851871  20180507121124018000000388268874          卡号1
#  490         1193    63272  20180507123321187000000023093621          卡号1
#  1             10   534047  20180507121002192000000023073000          卡号1
#  148          397   479499  20180507124657109000000388412231          卡号1
#  4113       10385  3078066  20180504172153411000000021229876          卡号1
#  1225        3200  1657504  20180507122342976000000388321116          卡号1
#  4567       11544  2181881  20180507123645665000000388370714          卡号1
#  2313        5863  2116253  20180507115755292000000388219722          卡号1
#  1708        4389   128330  20180507121546016000000388287585          卡号1
#  287          738  3298070  20180504173418801000000381676806          卡号1
# ...
